# %%
import numpy as np
import pandas as pd

# %%
titanic_src = pd.read_csv('/home/ANA522/Titanic.csv', sep=',')
titanic_src.shape
# Out:
# (891, 12)

# %%
titanic_src1 = titanic_src.copy()
titanic_src1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
TDS_Pclass_Sex = titanic_src.set_index(['Survived','Sex'])
TDS_Pclass_Sex_Sorted = TDS_Pclass_Sex.sort_index()
TDS_Pclass_Sex_Sorted
# Out:
#                  PassengerId  Pclass  \
# Survived Sex
# 0        female           15       3
#          female           19       3
#          female           25       3
#          female           39       3
#          female           41       3
# ...                      ...     ...
# 1        male            839       3
#          male            840       1
#          male            858       1
#          male            870       3
#          male            890       1
#
#                                                               Name   Age  \
# Survived Sex
# 0        female               Vestrom, Miss. Hulda Amanda Adolfina  14.0
#          female  Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
#          female                      Palsson, Miss. Torborg Danira   8.0
#          female                 Vander Planke, Miss. Augusta Maria  18.0
#          female     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0
# ...                                                            ...   ...
# 1        male                                      Chip, Mr. Chang  32.0
#          male                                 Marechal, Mr. Pierre   NaN
#          male                               Daly, Mr. Peter Denis   51.0
#          male                      Johnson, Master. Harold Theodor   4.0
#          male                                Behr, Mr. Karl Howell  26.0
#
#                  SibSp  Parch  Ticket     Fare Cabin Embarked
# Survived Sex
# 0        female      0      0  350406   7.8542   NaN        S
#          female      1      0  345763  18.0000   NaN        S
#          female      3      1  349909  21.0750   NaN        S
#          female      2      0  345764  18.0000   NaN        S
#          female      1      0    7546   9.4750   NaN        S
# ...                ...    ...     ...      ...   ...      ...
# 1        male        0      0    1601  56.4958   NaN        S
#          male        0      0   11774  29.7000   C47        C
#          male        0      0  113055  26.5500   E17        S
#          male        1      1  347742  11.1333   NaN        S
#          male        0      0  111369  30.0000  C148        C
#
# [891 rows x 10 columns]

# %%
###Q01: Transform the Titanic dataset with hierarchical indexing by the multiple index in the order of Survived, Sex, 
###and Pclass attributes.

TDS_Pclass_Sex = titanic_src.set_index(['Survived','Sex', 'Pclass'])
TDS_Pclass_Sex_Sorted = TDS_Pclass_Sex.sort_index()
TDS_Pclass_Sex_Sorted
# Out:
#                         PassengerId  \
# Survived Sex    Pclass
# 0        female 1               178
#                 1               298
#                 1               499
#                 2                42
#                 2               200
# ...                             ...
# 1        male   3               805
#                 3               822
#                 3               829
#                 3               839
#                 3               870
#
#                                                                      Name  \
# Survived Sex    Pclass
# 0        female 1                              Isham, Miss. Ann Elizabeth
#                 1                            Allison, Miss. Helen Loraine
#                 1         Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                 2       Turpin, Mrs. William John Robert (Dorothy Ann ...
#                 2                  Yrois, Miss. Henriette ("Mrs Harbeck")
# ...                                                                   ...
# 1        male   3                                 Hedman, Mr. Oskar Arvid
#                 3                                       Lulic, Mr. Nikola
#                 3                            McCormack, Mr. Thomas Joseph
#                 3                                         Chip, Mr. Chang
#                 3                         Johnson, Master. Harold Theodor
#
#                          Age  SibSp  Parch    Ticket      Fare    Cabin  \
# Survived Sex    Pclass
# 0        female 1       50.0      0      0  PC 17595   28.7125      C49
#                 1        2.0      1      2    113781  151.5500  C22 C26
#                 1       25.0      1      2    113781  151.5500  C22 C26
#                 2       27.0      1      0     11668   21.0000      NaN
#                 2       24.0      0      0    248747   13.0000      NaN
# ...                      ...    ...    ...       ...       ...      ...
# 1        male   3       27.0      0      0    347089    6.9750      NaN
#                 3       27.0      0      0    315098    8.6625      NaN
#                 3        NaN      0      0    367228    7.7500      NaN
#                 3       32.0      0      0      1601   56.4958      NaN
#                 3        4.0      1      1    347742   11.1333      NaN
#
#                        Embarked
# Survived Sex    Pclass
# 0        female 1             C
#                 1             S
#                 1             S
#                 2             S
#                 2             S
# ...                         ...
# 1        male   3             S
#                 3             S
#                 3             Q
#                 3             S
#                 3             S
#
# [891 rows x 9 columns]

# %%
###Q02: Transform the Titanic dataset with hierarchical indexing by the multiple index in the order of Sex and Pclass columns with
##only PassengerId, Survived, Age, Fare, and Embarked attributes included. Sort by row indices and name the new dataset as
##TDS_Sex_Pclass_Sorted to be used in the following questions.

TDS_Pclass_Sex = titanic_src.set_index(['Sex', 'Pclass'])
TDS_Pclass_Sex_Sorted = TDS_Pclass_Sex.sort_index()
TDS_Pclass_Sex_Sorted = TDS_Pclass_Sex_Sorted.loc[:, ('PassengerId', 'Survived', 'Age', 'Fare', 'Embarked')]
TDS_Pclass_Sex_Sorted
# Out:
#                PassengerId  Survived   Age      Fare Embarked
# Sex    Pclass
# female 1                 2         1  38.0   71.2833        C
#        1                 4         1  35.0   53.1000        S
#        1                12         1  58.0   26.5500        S
#        1                32         1   NaN  146.5208        C
#        1                53         1  49.0   76.7292        C
# ...                    ...       ...   ...       ...      ...
# male   3               878         0  19.0    7.8958        S
#        3               879         0   NaN    7.8958        S
#        3               882         0  33.0    7.8958        S
#        3               885         0  25.0    7.0500        S
#        3               891         0  32.0    7.7500        Q
#
# [891 rows x 5 columns]

# %%
###Q03: Follow up from Q02. Setup names for index and columns of the multi-index frame for TDS_Sex_Pclass_Sorted. Use “Gender”
###and “Roomclass” for index names respectively. Use “Profile” for columns’ name.

TDS_Pclass_Sex_Sorted.index.names = ['Gender', 'Roomclass']
TDS_Pclass_Sex_Sorted.columns.names = ['Profile']
TDS_Pclass_Sex_Sorted
# Out:
# Profile           PassengerId  Survived   Age      Fare Embarked
# Gender Roomclass
# female 1                    2         1  38.0   71.2833        C
#        1                    4         1  35.0   53.1000        S
#        1                   12         1  58.0   26.5500        S
#        1                   32         1   NaN  146.5208        C
#        1                   53         1  49.0   76.7292        C
# ...                       ...       ...   ...       ...      ...
# male   3                  878         0  19.0    7.8958        S
#        3                  879         0   NaN    7.8958        S
#        3                  882         0  33.0    7.8958        S
#        3                  885         0  25.0    7.0500        S
#        3                  891         0  32.0    7.7500        Q
#
# [891 rows x 5 columns]

# %%
###Q04: Create a Series of data for PassengerId, Survived, Age, Fare, and Embarked for every multi-index combination of Gender(Sex)
#and Roomclass(Pclass) in TDS_Sex_Pclass_Sorted


TDS_Pclass_Sex_Sorted.stack()
# Out:
# Gender  Roomclass  Profile
# female  1          PassengerId          2
#                    Survived             1
#                    Age               38.0
#                    Fare           71.2833
#                    Embarked             C
#                                    ...
# male    3          PassengerId        891
#                    Survived             0
#                    Age               32.0
#                    Fare              7.75
#                    Embarked             Q
# Length: 4276, dtype: object

# %%
###Q05: Adjust the hierarchical indexing so that the Roomclass is at the first level followed by Gender from TDS_Sex_Pclass_Sorted
#frame.swaplevel(0, 1).sort_index(level=0)

TDS_Pclass_Sex_Sorted.swaplevel(0, 1).sort_index(level=0)
# Out:
# Profile           PassengerId  Survived   Age      Fare Embarked
# Roomclass Gender
# 1         female            2         1  38.0   71.2833        C
#           female            4         1  35.0   53.1000        S
#           female           12         1  58.0   26.5500        S
#           female           32         1   NaN  146.5208        C
#           female           53         1  49.0   76.7292        C
# ...                       ...       ...   ...       ...      ...
# 3         male            878         0  19.0    7.8958        S
#           male            879         0   NaN    7.8958        S
#           male            882         0  33.0    7.8958        S
#           male            885         0  25.0    7.0500        S
#           male            891         0  32.0    7.7500        Q
#
# [891 rows x 5 columns]

# %%
###Q06: Compute total Fare of all passengers by Roomclass using TDS_Sex_Pclass_Sorted

TDS_Pclass_Sex_Sorted.Fare.sum(level='Roomclass', axis=0)
# Out:
# Roomclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
###Q07 Compute average Fare of all passengers by female and male using TDS_Sex_Pclass_Sorted

TDS_Pclass_Sex_Sorted.Fare.mean(level='Gender')
# Out:
# Gender
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
### Q08 Compute average Fare of all passengers from TDS_Sex_Pclass_Sorted up to 2 decimal points.

val = TDS_Pclass_Sex_Sorted['Fare'].mean().round(2)
print("The average Fare for all passengers:", val)
# Out:
# The average Fare for all passengers: 32.2

# %%
###Q09 Transform TDS_Sex_Pclass_Sorted so that PassengerId and Age are multiple indices while Gender and Roomclass are columns. 
###Display the result with Survived values only.

dataframe_reset = TDS_Pclass_Sex_Sorted.reset_index()
dataframe_reset.pivot(['PassengerId','Age'], ['Gender', 'Roomclass'], 'Survived')
# Out:
# Gender           female          male
# Roomclass             1   2    3    1    2    3
# PassengerId Age
# 1           22.0    NaN NaN  NaN  NaN  NaN  0.0
# 2           38.0    1.0 NaN  NaN  NaN  NaN  NaN
# 3           26.0    NaN NaN  1.0  NaN  NaN  NaN
# 4           35.0    1.0 NaN  NaN  NaN  NaN  NaN
# 5           35.0    NaN NaN  NaN  NaN  NaN  0.0
# ...                 ...  ..  ...  ...  ...  ...
# 887         27.0    NaN NaN  NaN  NaN  0.0  NaN
# 888         19.0    1.0 NaN  NaN  NaN  NaN  NaN
# 889         NaN     NaN NaN  0.0  NaN  NaN  NaN
# 890         26.0    NaN NaN  NaN  1.0  NaN  NaN
# 891         32.0    NaN NaN  NaN  NaN  NaN  0.0
#
# [891 rows x 6 columns]

# %%
### Q10 Create a dataframe from TDS_Sex_Pclass_Sorted that uses PassengerId as the key index to make all tuples of attribute 
##and value to be data entries in the table.

melted = pd.melt(TDS_Pclass_Sex_Sorted, ['PassengerId'])
melted
# Out:
#       PassengerId   Profile value
# 0               2  Survived     1
# 1               4  Survived     1
# 2              12  Survived     1
# 3              32  Survived     1
# 4              53  Survived     1
# ...           ...       ...   ...
# 3559          878  Embarked     S
# 3560          879  Embarked     S
# 3561          882  Embarked     S
# 3562          885  Embarked     S
# 3563          891  Embarked     Q
#
# [3564 rows x 3 columns]
